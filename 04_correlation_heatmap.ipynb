# %% [markdown]
# # Title
#
# ## Objective
#
# ## Steps
#
# ## Insights

# %%
import pandas as pdimport seaborn as snsimport matplotlib.pyplot as pltdf = pd.read_csv('data/heart.csv')sns.heatmap(df.corr(numeric_only=True), annot=True)plt.show()
