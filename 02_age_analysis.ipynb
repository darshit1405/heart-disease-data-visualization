# %% [markdown]
# # Title
#
# ## Objective
#
# ## Steps
#
# ## Insights

# %%
import pandas as pdimport seaborn as snsimport matplotlib.pyplot as pltdf = pd.read_csv('data/heart.csv')sns.histplot(df['age'], kde=True)plt.show()
